# %%
import pandas as pd
m_store=pd.read_csv('m_store.csv')

# %%
len(m_store)
# Out:
# 197

# %%
m_store.head()
# Out:
#    store_id store_name area_cd
# 0         1        昭島店      TK
# 1         2      あきる野店      TK
# 2         3        足立店      TK
# 3         4       北千住店      TK
# 4         5        綾瀬店      TK

# %%
m_area=pd.read_csv('m_area.csv')
m_area
# Out:
#   area_cd wide_area narrow_area
# 0      TK        東京          東京
# 1      KN       神奈川         神奈川
# 2      CH        千葉          千葉
# 3      SA        埼玉          埼玉
# 4      IB       北関東          茨城
# 5      TO       北関東          栃木
# 6      GU       北関東          群馬

# %%
tbl_order_4=pd.read_csv('tbl_order_202004.csv')
tbl_order_4
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 233255  25546308         3   C24617924         46          3700904
# 233256  91693481        45   C68997855          6         37852755
# 233257  57908119        36   C16123702         81         90372382
# 233258   7145625       174   C80733640         75         48265986
# 233259  31301192       151   C23758178          9         13847510
#
#        order_accept_date   delivered_date  takeout_flag  total_amount  status
# 0         2020/4/1 11:00   2020/4/1 11:18             1          4144       1
# 1         2020/4/1 11:00   2020/4/1 11:22             0          2877       2
# 2         2020/4/1 11:00   2020/4/1 11:15             0          2603       2
# 3         2020/4/1 11:00   2020/4/1 11:16             0          2732       2
# 4         2020/4/1 11:00   2020/4/1 11:53             0          2987       2
# ...                  ...              ...           ...           ...     ...
# 233255   2020/4/30 21:58  2020/4/30 22:19             0          2615       2
# 233256   2020/4/30 21:58  2020/4/30 22:13             0          2732       2
# 233257   2020/4/30 21:58  2020/4/30 22:47             0          2363       2
# 233258   2020/4/30 21:58  2020/4/30 22:32             0          2238       2
# 233259   2020/4/30 21:58  2020/4/30 22:52             0          1900       2
#
# [233260 rows x 10 columns]

# %%
tbl_order_5=pd.read_csv('tbl_order_202005.csv')
tbl_order_5
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       24742472        22   C90731046         22         80308413
# 1       11342919        56   C68678177         12         35725624
# 2       76451864        56   C79630016         46          2609869
# 3       28392539       192   C83895707         80         17111162
# 4       71706591       121   C36584528         93         22800835
# ...          ...       ...         ...        ...              ...
# 241134  47039360       154   C39765066         90         27121351
# 241135  61054188        94   C19465010         41         61513298
# 241136  45288914        11   C23883838         40         65359139
# 241137  41608372       149   C48350551         43         42138977
# 241138  40316733       169   C49087342         61         59737067
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0       2020-05-01 11:00:00  2020-05-01 11:22:00             1          2328
# 1       2020-05-01 11:00:00  2020-05-01 11:50:00             0          2987
# 2       2020-05-01 11:00:00  2020-05-01 11:32:00             0          2603
# 3       2020-05-01 11:00:00  2020-05-01 11:19:00             0          2603
# 4       2020-05-01 11:00:00  2020-05-01 11:17:00             0          2877
# ...                     ...                  ...           ...           ...
# 241134  2020-05-31 21:58:58  2020-05-31 22:42:58             1          2363
# 241135  2020-05-31 21:58:58  2020-05-31 22:40:58             0          2112
# 241136  2020-05-31 21:58:58  2020-05-31 22:38:58             0          3838
# 241137  2020-05-31 21:58:58  2020-05-31 22:52:58             0          1899
# 241138  2020-05-31 21:58:58  2020-05-31 22:08:58             0          3901
#
#         status
# 0            1
# 1            2
# 2            2
# 3            2
# 4            2
# ...        ...
# 241134       1
# 241135       2
# 241136       2
# 241137       2
# 241138       2
#
# [241139 rows x 10 columns]

# %%
order_all=pd.concat([tbl_order_4,tbl_order_5],ignore_index=True)
order_all
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 474394  47039360       154   C39765066         90         27121351
# 474395  61054188        94   C19465010         41         61513298
# 474396  45288914        11   C23883838         40         65359139
# 474397  41608372       149   C48350551         43         42138977
# 474398  40316733       169   C49087342         61         59737067
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0            2020/4/1 11:00       2020/4/1 11:18             1          4144
# 1            2020/4/1 11:00       2020/4/1 11:22             0          2877
# 2            2020/4/1 11:00       2020/4/1 11:15             0          2603
# 3            2020/4/1 11:00       2020/4/1 11:16             0          2732
# 4            2020/4/1 11:00       2020/4/1 11:53             0          2987
# ...                     ...                  ...           ...           ...
# 474394  2020-05-31 21:58:58  2020-05-31 22:42:58             1          2363
# 474395  2020-05-31 21:58:58  2020-05-31 22:40:58             0          2112
# 474396  2020-05-31 21:58:58  2020-05-31 22:38:58             0          3838
# 474397  2020-05-31 21:58:58  2020-05-31 22:52:58             0          1899
# 474398  2020-05-31 21:58:58  2020-05-31 22:08:58             0          3901
#
#         status
# 0            1
# 1            2
# 2            2
# 3            2
# 4            2
# ...        ...
# 474394       1
# 474395       2
# 474396       2
# 474397       2
# 474398       2
#
# [474399 rows x 10 columns]

# %%
len(order_all)==len(tbl_order_4)+len(tbl_order_5)
# Out:
# True

# %%
import os
current_dir=os.getcwd()
current_dir
# Out:
# 'c:\\Users\\yoshikoshi\\python_y'

# %%
os.listdir(current_dir)
# Out:
# ['.ipynb_checkpoints',
#  '.vscode',
#  'bike.tsv',
#  'Boston.csv',
#  'boston.pkl',
#  'boston_pca.csv',
#  'boston_scx.pkl',
#  'boston_scy.pkl',
#  'chap01_training.ipynb',
#  'chap04_05_training.ipynb',
#  'chap04_1.py',
#  'chap04_2.py',
#  'chap05_5training.ipynb',
#  'chap05_6_training.ipynb',
#  'chap05_training.py',
#  'chap06_numbers.ipynb',
#  'chap06_training.ipynb',
#  'chap07_training.ipynb',
#  'chap08_training.ipynb',
#  'chap10_training.ipynb',
#  'chap11_training.ipynb',
#  'chap12_training.ipynb',
#  'chap13_training.ipynb',
#  'chap14_training.ipynb',
#  'chap15_training.ipynb',
#  'cinema.csv',
#  'cinema.pkl',
#  'clustered_Wholesale.csv',
#  'docker-compose.yml',
#  'Dockerfile',
#  'ex1.csv',
#  'ex2.csv',
#  'hello python.py',
#  'iris.csv',
#  'irismodle.pkl',
#  'KinokoTakenoko.pkl',
#  'knock_1_10.ipynb',
#  'KvsT.csv',
#  'MLSys_100Knocks',
#  'm_area.csv',
#  'm_store.csv',
#  'Numbers3.csv',
#  'order_data.csv',
#  'output_data',
#  'sukkiri-ml-codes',
#  'Survived.csv',
#  'survived.pkl',
#  'tbl_order_202004.csv',
#  'tbl_order_202005.csv',
#  'tbl_order_202006.csv',
#  'temp.json',
#  'test0.png',
#  'test1.png',
#  'weather.csv',
#  'Wholesale.csv']

# %%
tbl_order_file=os.path.join(current_dir,'tbl_order_*.csv')
tbl_order_file
# Out:
# 'c:\\Users\\yoshikoshi\\python_y\\tbl_order_*.csv'

# %%
import glob
tbl_order_files=glob.glob(tbl_order_file)
tbl_order_files
# Out:
# ['c:\\Users\\yoshikoshi\\python_y\\tbl_order_202004.csv',
#  'c:\\Users\\yoshikoshi\\python_y\\tbl_order_202005.csv',
#  'c:\\Users\\yoshikoshi\\python_y\\tbl_order_202006.csv']

# %%
order_all=pd.DataFrame()
file=tbl_order_files[0]
order_data=pd.read_csv(file)
print(f'{file}:{len(order_data)}')
order_all=pd.concat([order_all,order_all,order_data],ignore_index=True)
order_all
# Out:
# c:\Users\yoshikoshi\python_y\tbl_order_202004.csv:233260
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 233255  25546308         3   C24617924         46          3700904
# 233256  91693481        45   C68997855          6         37852755
# 233257  57908119        36   C16123702         81         90372382
# 233258   7145625       174   C80733640         75         48265986
# 233259  31301192       151   C23758178          9         13847510
#
#        order_accept_date   delivered_date  takeout_flag  total_amount  status
# 0         2020/4/1 11:00   2020/4/1 11:18             1          4144       1
# 1         2020/4/1 11:00   2020/4/1 11:22             0          2877       2
# 2         2020/4/1 11:00   2020/4/1 11:15             0          2603       2
# 3         2020/4/1 11:00   2020/4/1 11:16             0          2732       2
# 4         2020/4/1 11:00   2020/4/1 11:53             0          2987       2
# ...                  ...              ...           ...           ...     ...
# 233255   2020/4/30 21:58  2020/4/30 22:19             0          2615       2
# 233256   2020/4/30 21:58  2020/4/30 22:13             0          2732       2
# 233257   2020/4/30 21:58  2020/4/30 22:47             0          2363       2
# 233258   2020/4/30 21:58  2020/4/30 22:32             0          2238       2
# 233259   2020/4/30 21:58  2020/4/30 22:52             0          1900       2
#
# [233260 rows x 10 columns]

# %%
order_all=pd.DataFrame()
for file in tbl_order_files:
    order_data=pd.read_csv(file)
    print(f'{file}:{len(order_data)}')
    order_all=pd.concat([order_all,order_data],ignore_index=True)
# Out:
# c:\Users\yoshikoshi\python_y\tbl_order_202004.csv:233260
# c:\Users\yoshikoshi\python_y\tbl_order_202005.csv:241139
# c:\Users\yoshikoshi\python_y\tbl_order_202006.csv:233301

# %%
order_all
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 707695  90872494       191   C35992970         46         51884378
# 707696  30167637        35   C53126526         88          6295273
# 707697  85345862       118   C25099070         32         15733308
# 707698  73038887       100   C27421314         84         67608099
# 707699  14799648        39   C90614204          5         13300147
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0            2020/4/1 11:00       2020/4/1 11:18             1          4144
# 1            2020/4/1 11:00       2020/4/1 11:22             0          2877
# 2            2020/4/1 11:00       2020/4/1 11:15             0          2603
# 3            2020/4/1 11:00       2020/4/1 11:16             0          2732
# 4            2020/4/1 11:00       2020/4/1 11:53             0          2987
# ...                     ...                  ...           ...           ...
# 707695  2020-06-30 21:58:58  2020-06-30 22:43:58             1          2112
# 707696  2020-06-30 21:58:58  2020-06-30 22:36:58             0          4462
# 707697  2020-06-30 21:58:58  2020-06-30 22:42:58             0          3865
# 707698  2020-06-30 21:58:58  2020-06-30 22:21:58             0          3319
# 707699  2020-06-30 21:58:58  2020-06-30 22:38:58             0          2064
#
#         status
# 0            1
# 1            2
# 2            2
# 3            2
# 4            2
# ...        ...
# 707695       1
# 707696       2
# 707697       2
# 707698       2
# 707699       2
#
# [707700 rows x 10 columns]

# %%
order_all.isnull().sum()
# Out:
# order_id             0
# store_id             0
# customer_id          0
# coupon_cd            0
# sales_detail_id      0
# order_accept_date    0
# delivered_date       0
# takeout_flag         0
# total_amount         0
# status               0
# dtype: int64

# %%
order_all.describe()
# Out:
#            order_id       store_id      coupon_cd  sales_detail_id  \
# count  7.077000e+05  707700.000000  707700.000000     7.077000e+05
# mean   5.000989e+07     103.934565      49.514363     5.000335e+07
# std    2.889226e+07      86.374451      28.882605     2.885575e+07
# min    2.200000e+01       1.000000       0.000000     4.600000e+01
# 25%    2.501247e+07      51.000000      25.000000     2.504502e+07
# 50%    4.999655e+07      99.000000      49.000000     5.004506e+07
# 75%    7.508014e+07     148.000000      75.000000     7.499707e+07
# max    9.999980e+07     999.000000      99.000000     9.999965e+07
#
#         takeout_flag   total_amount         status
# count  707700.000000  707700.000000  707700.000000
# mean        0.259864    2960.651814       3.082908
# std         0.438560     954.378771       2.836278
# min         0.000000     698.000000       1.000000
# 25%         0.000000    2308.000000       2.000000
# 50%         0.000000    2808.000000       2.000000
# 75%         1.000000    3617.000000       2.000000
# max         1.000000    5100.000000       9.000000

# %%
order_all['total_amount'].describe()
# Out:
# count    707700.000000
# mean       2960.651814
# std         954.378771
# min         698.000000
# 25%        2308.000000
# 50%        2808.000000
# 75%        3617.000000
# max        5100.000000
# Name: total_amount, dtype: float64

# %%
print(order_all["order_accept_date"].min())
print(order_all["order_accept_date"].max())
print(order_all["delivered_date"].min())
print(order_all["delivered_date"].max())
# Out:
# 2020-05-01 11:00:00
# 2020/4/9 21:58
# 2020-05-01 11:13:02
# 2020/4/9 23:14

# %%
order_data=order_all.loc[order_all['store_id']!=999]
order_data
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 707695  90872494       191   C35992970         46         51884378
# 707696  30167637        35   C53126526         88          6295273
# 707697  85345862       118   C25099070         32         15733308
# 707698  73038887       100   C27421314         84         67608099
# 707699  14799648        39   C90614204          5         13300147
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0            2020/4/1 11:00       2020/4/1 11:18             1          4144
# 1            2020/4/1 11:00       2020/4/1 11:22             0          2877
# 2            2020/4/1 11:00       2020/4/1 11:15             0          2603
# 3            2020/4/1 11:00       2020/4/1 11:16             0          2732
# 4            2020/4/1 11:00       2020/4/1 11:53             0          2987
# ...                     ...                  ...           ...           ...
# 707695  2020-06-30 21:58:58  2020-06-30 22:43:58             1          2112
# 707696  2020-06-30 21:58:58  2020-06-30 22:36:58             0          4462
# 707697  2020-06-30 21:58:58  2020-06-30 22:42:58             0          3865
# 707698  2020-06-30 21:58:58  2020-06-30 22:21:58             0          3319
# 707699  2020-06-30 21:58:58  2020-06-30 22:38:58             0          2064
#
#         status
# 0            1
# 1            2
# 2            2
# 3            2
# 4            2
# ...        ...
# 707695       1
# 707696       2
# 707697       2
# 707698       2
# 707699       2
#
# [703880 rows x 10 columns]

# %%
order_data=pd.merge(order_data,m_store,on='store_id',how='left')
order_data
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 703875  90872494       191   C35992970         46         51884378
# 703876  30167637        35   C53126526         88          6295273
# 703877  85345862       118   C25099070         32         15733308
# 703878  73038887       100   C27421314         84         67608099
# 703879  14799648        39   C90614204          5         13300147
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0            2020/4/1 11:00       2020/4/1 11:18             1          4144
# 1            2020/4/1 11:00       2020/4/1 11:22             0          2877
# 2            2020/4/1 11:00       2020/4/1 11:15             0          2603
# 3            2020/4/1 11:00       2020/4/1 11:16             0          2732
# 4            2020/4/1 11:00       2020/4/1 11:53             0          2987
# ...                     ...                  ...           ...           ...
# 703875  2020-06-30 21:58:58  2020-06-30 22:43:58             1          2112
# 703876  2020-06-30 21:58:58  2020-06-30 22:36:58             0          4462
# 703877  2020-06-30 21:58:58  2020-06-30 22:42:58             0          3865
# 703878  2020-06-30 21:58:58  2020-06-30 22:21:58             0          3319
# 703879  2020-06-30 21:58:58  2020-06-30 22:38:58             0          2064
#
#         status store_name area_cd
# 0            1        浅草店      TK
# 1            2        目黒店      TK
# 2            2        本郷店      TK
# 3            2        栃木店      TO
# 4            2       伊勢崎店      GU
# ...        ...        ...     ...
# 703875       1       伊勢崎店      GU
# 703876       2       代々木店      TK
# 703877       2        磯子店      KN
# 703878       2        中原店      KN
# 703879       2        杉並店      TK
#
# [703880 rows x 12 columns]

# %%
order_data=pd.merge(order_data,m_area,on='area_cd',how='left')
order_data
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 703875  90872494       191   C35992970         46         51884378
# 703876  30167637        35   C53126526         88          6295273
# 703877  85345862       118   C25099070         32         15733308
# 703878  73038887       100   C27421314         84         67608099
# 703879  14799648        39   C90614204          5         13300147
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0            2020/4/1 11:00       2020/4/1 11:18             1          4144
# 1            2020/4/1 11:00       2020/4/1 11:22             0          2877
# 2            2020/4/1 11:00       2020/4/1 11:15             0          2603
# 3            2020/4/1 11:00       2020/4/1 11:16             0          2732
# 4            2020/4/1 11:00       2020/4/1 11:53             0          2987
# ...                     ...                  ...           ...           ...
# 703875  2020-06-30 21:58:58  2020-06-30 22:43:58             1          2112
# 703876  2020-06-30 21:58:58  2020-06-30 22:36:58             0          4462
# 703877  2020-06-30 21:58:58  2020-06-30 22:42:58             0          3865
# 703878  2020-06-30 21:58:58  2020-06-30 22:21:58             0          3319
# 703879  2020-06-30 21:58:58  2020-06-30 22:38:58             0          2064
#
#         status store_name area_cd wide_area narrow_area
# 0            1        浅草店      TK        東京          東京
# 1            2        目黒店      TK        東京          東京
# 2            2        本郷店      TK        東京          東京
# 3            2        栃木店      TO       北関東          栃木
# 4            2       伊勢崎店      GU       北関東          群馬
# ...        ...        ...     ...       ...         ...
# 703875       1       伊勢崎店      GU       北関東          群馬
# 703876       2       代々木店      TK        東京          東京
# 703877       2        磯子店      KN       神奈川         神奈川
# 703878       2        中原店      KN       神奈川         神奈川
# 703879       2        杉並店      TK        東京          東京
#
# [703880 rows x 14 columns]

# %%
order_data.loc[order_data['takeout_flag']==0,'takeout_name']='デリバリー'
order_data.loc[order_data['takeout_flag']==1,'takeout_name']='お持ち帰り'
order_data
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 703875  90872494       191   C35992970         46         51884378
# 703876  30167637        35   C53126526         88          6295273
# 703877  85345862       118   C25099070         32         15733308
# 703878  73038887       100   C27421314         84         67608099
# 703879  14799648        39   C90614204          5         13300147
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0            2020/4/1 11:00       2020/4/1 11:18             1          4144
# 1            2020/4/1 11:00       2020/4/1 11:22             0          2877
# 2            2020/4/1 11:00       2020/4/1 11:15             0          2603
# 3            2020/4/1 11:00       2020/4/1 11:16             0          2732
# 4            2020/4/1 11:00       2020/4/1 11:53             0          2987
# ...                     ...                  ...           ...           ...
# 703875  2020-06-30 21:58:58  2020-06-30 22:43:58             1          2112
# 703876  2020-06-30 21:58:58  2020-06-30 22:36:58             0          4462
# 703877  2020-06-30 21:58:58  2020-06-30 22:42:58             0          3865
# 703878  2020-06-30 21:58:58  2020-06-30 22:21:58             0          3319
# 703879  2020-06-30 21:58:58  2020-06-30 22:38:58             0          2064
#
#         status store_name area_cd wide_area narrow_area takeout_name
# 0            1        浅草店      TK        東京          東京        お持ち帰り
# 1            2        目黒店      TK        東京          東京        デリバリー
# 2            2        本郷店      TK        東京          東京        デリバリー
# 3            2        栃木店      TO       北関東          栃木        デリバリー
# 4            2       伊勢崎店      GU       北関東          群馬        デリバリー
# ...        ...        ...     ...       ...         ...          ...
# 703875       1       伊勢崎店      GU       北関東          群馬        お持ち帰り
# 703876       2       代々木店      TK        東京          東京        デリバリー
# 703877       2        磯子店      KN       神奈川         神奈川        デリバリー
# 703878       2        中原店      KN       神奈川         神奈川        デリバリー
# 703879       2        杉並店      TK        東京          東京        デリバリー
#
# [703880 rows x 15 columns]

# %%
order_data.loc[order_data['status']==0,'status_name']='受付'
order_data.loc[order_data['status']==1,'status_name']='お支払済'
order_data.loc[order_data['status']==2,'status_name']='お渡し済'
order_data.loc[order_data['status']==9,'status_name']='キャンセル'
order_data
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       79339111        49   C26387220         50         67393872
# 1       18941733        85   C48773811         26         91834983
# 2       56217880        76   C66287421         36         64409634
# 3       28447783       190   C41156423         19         73032165
# 4       32576156       191   C54568117         71         23281182
# ...          ...       ...         ...        ...              ...
# 703875  90872494       191   C35992970         46         51884378
# 703876  30167637        35   C53126526         88          6295273
# 703877  85345862       118   C25099070         32         15733308
# 703878  73038887       100   C27421314         84         67608099
# 703879  14799648        39   C90614204          5         13300147
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0            2020/4/1 11:00       2020/4/1 11:18             1          4144
# 1            2020/4/1 11:00       2020/4/1 11:22             0          2877
# 2            2020/4/1 11:00       2020/4/1 11:15             0          2603
# 3            2020/4/1 11:00       2020/4/1 11:16             0          2732
# 4            2020/4/1 11:00       2020/4/1 11:53             0          2987
# ...                     ...                  ...           ...           ...
# 703875  2020-06-30 21:58:58  2020-06-30 22:43:58             1          2112
# 703876  2020-06-30 21:58:58  2020-06-30 22:36:58             0          4462
# 703877  2020-06-30 21:58:58  2020-06-30 22:42:58             0          3865
# 703878  2020-06-30 21:58:58  2020-06-30 22:21:58             0          3319
# 703879  2020-06-30 21:58:58  2020-06-30 22:38:58             0          2064
#
#         status store_name area_cd wide_area narrow_area takeout_name  \
# 0            1        浅草店      TK        東京          東京        お持ち帰り
# 1            2        目黒店      TK        東京          東京        デリバリー
# 2            2        本郷店      TK        東京          東京        デリバリー
# 3            2        栃木店      TO       北関東          栃木        デリバリー
# 4            2       伊勢崎店      GU       北関東          群馬        デリバリー
# ...        ...        ...     ...       ...         ...          ...
# 703875       1       伊勢崎店      GU       北関東          群馬        お持ち帰り
# 703876       2       代々木店      TK        東京          東京        デリバリー
# 703877       2        磯子店      KN       神奈川         神奈川        デリバリー
# 703878       2        中原店      KN       神奈川         神奈川        デリバリー
# 703879       2        杉並店      TK        東京          東京        デリバリー
#
#        status_name
# 0             お支払済
# 1             お渡し済
# 2             お渡し済
# 3             お渡し済
# 4             お渡し済
# ...            ...
# 703875        お支払済
# 703876        お渡し済
# 703877        お渡し済
# 703878        お渡し済
# 703879        お渡し済
#
# [703880 rows x 16 columns]

# %%
output_dir=os.path.join(current_dir,'output_data')
os.makedirs(output_dir,exist_ok=True)

# %%
output_file=os.path.join(output_dir,'order_data.csv')
order_data.to_csv(output_file,index=False)

# %%
import pandas as pd
import os
import glob

m_store=pd.read_csv('m_store.csv')
m_area=pd.read_csv('m_area.csv')

current_dir=os.getcwd()
tbl_order_file=os.path.join(current_dir,'tbl_order_*.csv')
tbl_order_files=glob.glob(tbl_order_file)
order_all=pd.DataFrame()

for file in tbl_order_files:
    order_data=pd.read_csv(file)
    print(f'{file}:{len(order_data)}')
    order_all=pd.concat([order_all,order_data],ignore_index=True)

    order_data=order_all.loc[order_all['store_id']!=999]

    order_data=pd.merge(order_data,m_store,on='store_id',how='left')
    order_data=pd.merge(order_data,m_area,on='area_cd',how='left')

    order_data.loc[order_data['takeout_flag']==0,'takeout_name']='デリバリー'
    order_data.loc[order_data['takeout_flag']==1,'takeout_name']='お持ち帰り'

    order_data.loc[order_data['status']==0,'status_name']='受付'
    order_data.loc[order_data['status']==1,'status_name']='お支払済'
    order_data.loc[order_data['status']==2,'status_name']='お渡し済'
    order_data.loc[order_data['status']==9,'status_name']='キャンセル'

    output_dir=os.path.join(current_dir,'output_data')
    os.makedirs(output_dir,exist_ok=True)
    output_file=os.path.join(output_dir,'order_data.csv')
    order_data.to_csv(output_file,index=False)
# Out:
# c:\Users\yoshikoshi\python_y\tbl_order_202004.csv:233260
# c:\Users\yoshikoshi\python_y\tbl_order_202005.csv:241139
# c:\Users\yoshikoshi\python_y\tbl_order_202006.csv:233301

# %%
import pandas as pd
order_data=pd.read_csv('order_data.csv')
print(len(order_data))
order_data.head()
# Out:
# 703880
#    order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0  79339111        49   C26387220         50         67393872
# 1  18941733        85   C48773811         26         91834983
# 2  56217880        76   C66287421         36         64409634
# 3  28447783       190   C41156423         19         73032165
# 4  32576156       191   C54568117         71         23281182
#
#   order_accept_date  delivered_date  takeout_flag  total_amount  status  \
# 0    2020/4/1 11:00  2020/4/1 11:18             1          4144       1
# 1    2020/4/1 11:00  2020/4/1 11:22             0          2877       2
# 2    2020/4/1 11:00  2020/4/1 11:15             0          2603       2
# 3    2020/4/1 11:00  2020/4/1 11:16             0          2732       2
# 4    2020/4/1 11:00  2020/4/1 11:53             0          2987       2
#
#   store_name area_cd wide_area narrow_area takeout_name status_name
# 0        浅草店      TK        東京          東京        お持ち帰り        お支払済
# 1        目黒店      TK        東京          東京        デリバリー        お渡し済
# 2        本郷店      TK        東京          東京        デリバリー        お渡し済
# 3        栃木店      TO       北関東          栃木        デリバリー        お渡し済
# 4       伊勢崎店      GU       北関東          群馬        デリバリー        お渡し済

# %%
order_data=order_data.loc[(order_data['status']==1)|(order_data['status']==2)]
print(len(order_data))
order_data.columns
# Out:
# 574436
# Index(['order_id', 'store_id', 'customer_id', 'coupon_cd', 'sales_detail_id',
#        'order_accept_date', 'delivered_date', 'takeout_flag', 'total_amount',
#        'status', 'store_name', 'area_cd', 'wide_area', 'narrow_area',
#        'takeout_name', 'status_name'],
#       dtype='object')

# %%
analyze_data=order_data[['store_id', 'customer_id', 'coupon_cd',
       'order_accept_date', 'delivered_date', 'total_amount','store_name', 'wide_area', 'narrow_area','takeout_name', 'status_name']]
print(analyze_data.shape)
analyze_data.head()
# Out:
# (574436, 11)
#    store_id customer_id  coupon_cd order_accept_date  delivered_date  \
# 0        49   C26387220         50    2020/4/1 11:00  2020/4/1 11:18
# 1        85   C48773811         26    2020/4/1 11:00  2020/4/1 11:22
# 2        76   C66287421         36    2020/4/1 11:00  2020/4/1 11:15
# 3       190   C41156423         19    2020/4/1 11:00  2020/4/1 11:16
# 4       191   C54568117         71    2020/4/1 11:00  2020/4/1 11:53
#
#    total_amount store_name wide_area narrow_area takeout_name status_name
# 0          4144        浅草店        東京          東京        お持ち帰り        お支払済
# 1          2877        目黒店        東京          東京        デリバリー        お渡し済
# 2          2603        本郷店        東京          東京        デリバリー        お渡し済
# 3          2732        栃木店       北関東          栃木        デリバリー        お渡し済
# 4          2987       伊勢崎店       北関東          群馬        デリバリー        お渡し済

# %%
analyze_data.describe()
# Out:
#             store_id      coupon_cd   total_amount
# count  574436.000000  574436.000000  574436.000000
# mean       99.113844      49.478758    2960.087555
# std        55.913615      28.888993     954.282731
# min         1.000000       0.000000     698.000000
# 25%        51.000000      24.000000    2308.000000
# 50%        99.000000      49.000000    2808.000000
# 75%       147.000000      75.000000    3617.000000
# max       196.000000      99.000000    5100.000000

# %%
analyze_data.dtypes
# Out:
# store_id              int64
# customer_id          object
# coupon_cd             int64
# order_accept_date    object
# delivered_date       object
# total_amount          int64
# store_name           object
# wide_area            object
# narrow_area          object
# takeout_name         object
# status_name          object
# dtype: object

# %%
analyze_data[['store_id','coupon_cd']]=analyze_data[['store_id','coupon_cd']].astype(str)
analyze_data.dtypes
# Out:
# C:\Users\yoshikoshi\AppData\Local\Temp\ipykernel_10800\130839265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analyze_data[['store_id','coupon_cd']]=analyze_data[['store_id','coupon_cd']].astype(str)
# store_id             object
# customer_id          object
# coupon_cd            object
# order_accept_date    object
# delivered_date       object
# total_amount          int64
# store_name           object
# wide_area            object
# narrow_area          object
# takeout_name         object
# status_name          object
# dtype: object

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
analyze_data.describe()
# Out:
#         total_amount
# count  574436.000000
# mean     2960.087555
# std       954.282731
# min       698.000000
# 25%      2308.000000
# 50%      2808.000000
# 75%      3617.000000
# max      5100.000000

# %%
analyze_data["order_accept_date"]
# Out:
# 0              2020/4/1 11:00
# 1              2020/4/1 11:00
# 2              2020/4/1 11:00
# 3              2020/4/1 11:00
# 4              2020/4/1 11:00
#                  ...
# 703875    2020-06-30 21:58:58
# 703876    2020-06-30 21:58:58
# 703877    2020-06-30 21:58:58
# 703878    2020-06-30 21:58:58
# 703879    2020-06-30 21:58:58
# Name: order_accept_date, Length: 574436, dtype: object

# %%
analyze_data['order_accept_date']=pd.to_datetime(analyze_data['order_accept_date'])
analyze_data['order_accept_month']=analyze_data['order_accept_date'].dt.strftime('%Y%m')
analyze_data[['order_accept_date','order_accept_month']].head()
# Out:
#     order_accept_date order_accept_month
# 0 2020-04-01 11:00:00             202004
# 1 2020-04-01 11:00:00             202004
# 2 2020-04-01 11:00:00             202004
# 3 2020-04-01 11:00:00             202004
# 4 2020-04-01 11:00:00             202004

# %%
analyze_data["delivered_date"]
# Out:
# 0              2020/4/1 11:18
# 1              2020/4/1 11:22
# 2              2020/4/1 11:15
# 3              2020/4/1 11:16
# 4              2020/4/1 11:53
#                  ...
# 703875    2020-06-30 22:43:58
# 703876    2020-06-30 22:36:58
# 703877    2020-06-30 22:42:58
# 703878    2020-06-30 22:21:58
# 703879    2020-06-30 22:38:58
# Name: delivered_date, Length: 574436, dtype: object

# %%
analyze_data['delivered_date']=pd.to_datetime(analyze_data['delivered_date'])
analyze_data['delivered_month']=analyze_data['delivered_date'].dt.strftime("%Y%m")
analyze_data[['delivered_date','delivered_month']].head()
# Out:
#        delivered_date delivered_month
# 0 2020-04-01 11:18:00          202004
# 1 2020-04-01 11:22:00          202004
# 2 2020-04-01 11:15:00          202004
# 3 2020-04-01 11:16:00          202004
# 4 2020-04-01 11:53:00          202004

# %%
month_data=analyze_data.groupby('order_accept_month')
month_data.describe()
# Out:
#                    total_amount                                          \
#                           count         mean         std    min     25%
# order_accept_month
# 202004                 189414.0  2959.440638  954.271169  698.0  2308.0
# 202005                 195684.0  2960.327799  954.823248  698.0  2308.0
# 202006                 189338.0  2960.486437  953.740057  698.0  2308.0
#
#
#                        50%     75%     max
# order_accept_month
# 202004              2808.0  3586.0  5100.0
# 202005              2808.0  3586.0  5100.0
# 202006              2808.0  3617.0  5100.0

# %%
month_data.sum()
# Out:
#                     total_amount
# order_accept_month
# 202004                 560559489
# 202005                 579288785
# 202006                 560532581

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
month_data.sum().plot()
# Out:
# <Axes: xlabel='order_accept_month'>

# %%
month_data.mean().plot()
# Out:
# <Axes: xlabel='order_accept_month'>

# %%
plt.hist(analyze_data['total_amount'])
# Out:
# (array([ 21524.,      0.,  48969., 135664., 111217.,  77622.,  54146.,
#          59814.,  34394.,  31086.]),
#  array([ 698. , 1138.2, 1578.4, 2018.6, 2458.8, 2899. , 3339.2, 3779.4,
#         4219.6, 4659.8, 5100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(analyze_data['total_amount'],bins=21)
# Out:
# (array([10728., 10796.,     0.,     0.,     0., 48969., 45777., 78334.,
#         23175., 66451., 44368., 38745., 27653., 42503., 12508., 35285.,
#         23739., 11151., 23168., 22649.,  8437.]),
#  array([ 698.        ,  907.61904762, 1117.23809524, 1326.85714286,
#         1536.47619048, 1746.0952381 , 1955.71428571, 2165.33333333,
#         2374.95238095, 2584.57142857, 2794.19047619, 3003.80952381,
#         3213.42857143, 3423.04761905, 3632.66666667, 3842.28571429,
#         4051.9047619 , 4261.52380952, 4471.14285714, 4680.76190476,
#         4890.38095238, 5100.        ]),
#  <BarContainer object of 21 artists>)

# %%
pre_data=pd.pivot_table(analyze_data,index='order_accept_month',columns='narrow_area',values='total_amount',aggfunc='mean')
pre_data
# Out:
# narrow_area                  千葉           埼玉           東京           栃木  \
# order_accept_month
# 202004              2959.062000  2976.519634  2960.592173  2992.173548
# 202005              2953.545504  2977.290771  2962.603059  2998.165682
# 202006              2955.761885  2976.988380  2962.949987  2991.542844
#
# narrow_area                 神奈川           群馬           茨城
# order_accept_month
# 202004              2948.001171  2942.046543  2947.479814
# 202005              2949.597054  2948.269611  2941.796835
# 202006              2950.520464  2945.504744  2935.951783

# %%
#import japanize_matplotlib
#日本語表記できないのでローマ字で

plt.plot(list(pre_data.index),pre_data['東京'],label='tokyo')
plt.plot(list(pre_data.index),pre_data['神奈川'],label='kanagawa')
plt.plot(list(pre_data.index),pre_data['埼玉'],label='saitama')
plt.plot(list(pre_data.index),pre_data['千葉'],label='chiba')
plt.plot(list(pre_data.index),pre_data['茨城'],label='ibaraki')
plt.plot(list(pre_data.index),pre_data['栃木'],label='tochigi')
plt.plot(list(pre_data.index),pre_data['群馬'],label='gunma')
plt.legend()

# %%
store_clustering=analyze_data.groupby('store_id').agg(['size','mean','median','max','min'])['total_amount']
store_clustering.reset_index(inplace=True,drop=True)
print(len(store_clustering))
store_clustering.head()
# Out:
# 196
#    size         mean  median   max   min
# 0  2877  3129.834897  3050.0  5100  1857
# 1  2294  2989.003923  2677.0  5100   698
# 2  3776  2947.170286  2808.0  5100   698
# 3  1740  3074.770115  2877.0  4744  1899
# 4  2760  2845.661594  2791.0  4744   698

# %%
import seaborn as sns
hexbin=sns.jointplot(x='mean',y='size',data=store_clustering,kind='hex')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 import seaborn as sns
# ----> 2 hexbin=sns.jointplot(x='mean',y='size',data=store_clustering,kind='hex')
#
# NameError: name 'store_clustering' is not defined

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
