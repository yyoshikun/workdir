# %%
#001 フォルダー作成
import os
import pandas as pd

data_dir="Num_3_predict"
input_dir=os.path.join(data_dir,"00_input")
output_dir=os.path.join(data_dir,"01_output")
output_results_dir=os.path.join(data_dir,"02_output_results")
master_dir=os.path.join(data_dir,"03_master")
display(input_dir)
# Out:
# 'Num_3_predict/00_input'

# %%
#002　フォルダー出力
os.makedirs(input_dir,exist_ok=True)
os.makedirs(output_dir,exist_ok=True)
os.makedirs(output_results_dir,exist_ok=True)
os.makedirs(master_dir,exist_ok=True)

# %%
#003　csv_取得
import glob
Num_3_file=os.path.join(input_dir,'Num_3_*.csv')
Num_3_paths=glob.glob(Num_3_file)
display(Num_3_paths)
# Out:
# ['Num_3_predict/00_input/Num_3_2018.csv',
#  'Num_3_predict/00_input/Num_3_2019.csv',
#  'Num_3_predict/00_input/Num_3_2020.csv',
#  'Num_3_predict/00_input/Num_3_2021.csv',
#  'Num_3_predict/00_input/Num_3_2022.csv']

# %%
#004 csv_data 呼び出し
Num_3_predict_dir=os.path.join(data_dir,'00_input//001_all_data')
Num_3_file='Num_3_2023.csv' #西暦ごと
Num_3=pd.read_csv(os.path.join(Num_3_predict_dir,Num_3_file))
display(Num_3.head())

#Num_3_file=pd.read_csv(os.path.join('Num_3_*.csv'))
#Num_3_file.head()
# Out:
#    No       date day of week  Lottery_result  hundreds_place  tens_place  \
# 0   1   2023/1/4   Wednesday              91               0           9
# 1   2   2023/1/5    Thursday             433               4           3
# 2   3   2023/1/6      Friday             185               1           8
# 3   4   2023/1/9      Monday             661               6           6
# 4   5  2023/1/10     Tuesday             203               2           0
#
#    ones_place
# 0           1
# 1           3
# 2           5
# 3           1
# 4           3

# %%
#005 欠損値の確認---どちらでもOK---
#Num_3.isna().sum 
Num_3.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        No   date  day of week  Lottery_result  hundreds_place  tens_place  \
# 0   False  False        False           False           False       False
# 1   False  False        False           False           False       False
# 2   False  False        False           False           False       False
# 3   False  False        False           False           False       False
# 4   False  False        False           False           False       False
# ..    ...    ...          ...             ...             ...         ...
# 83  False  False        False           False           False       False
# 84  False  False        False           False           False       False
# 85  False  False        False           False           False       False
# 86  False  False        False           False           False       False
# 87  False  False        False           False           False       False
#
#     ones_place
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 83       False
# 84       False
# 85       False
# 86       False
# 87       False
#
# [88 rows x 7 columns]>

# %%
#006 欠損値を除外
Num_3=Num_3.loc[Num_3['date']!= 999]

# %%
#007 2010_2022 csv結合前にファイル確認
import pandas as pd
Num_3_predict_dir=os.path.join(data_dir,'00_input//001_all_data')
Num_3_file='Num_3_2010.csv' #西暦ごと
Num_3=pd.read_csv(os.path.join(Num_3_predict_dir,Num_3_file))
display(Num_3.head())

#Num_3_data=pd.read_csv('00_input\\Num_3_2010.csv')
#display(Num_3_data.head())
# Out:
#    No      date day of week  Lottery_result  hundreds_place  tens_place  \
# 0   1  2010/1/4      Monday             232               2           3
# 1   2  2010/1/5     Tuesday             619               6           1
# 2   3  2010/1/6   Wednesday             112               1           1
# 3   4  2010/1/7    Thursday             845               8           4
# 4   5  2010/1/8      Friday             523               5           2
#
#    ones_place
# 0           2
# 1           9
# 2           2
# 3           5
# 4           3

# %%
#007 2010_2022 csv結合前にファイル確認したほうがよい
import pandas as pd
Num_3_all=pd.DataFrame()
file=Num_3_paths[0]
Num_3_data=pd.read_csv(file)

display(f'{file}:{len(Num_3_data)}')
Num_3_all=pd.concat([Num_3_all,Num_3_data],ignore_index=True)
Num_3_all
# Out:
# 'Num_3_predict/00_input/Num_3_2018.csv:257'
#       No        date  Lottery_result  hundreds_place  tens_place  ones_place
# 0      1    2018/1/4             858               8           5           8
# 1      2    2018/1/5             384               3           8           4
# 2      3    2018/1/8             976               9           7           6
# 3      4    2018/1/9             930               9           3           0
# 4      5   2018/1/10             634               6           3           4
# ..   ...         ...             ...             ...         ...         ...
# 252  253  2018/12/24             329               3           2           9
# 253  254  2018/12/25             442               4           4           2
# 254  255  2018/12/26             644               6           4           4
# 255  256  2018/12/27              80               0           8           0
# 256  257  2018/12/28             234               2           3           4
#
# [257 rows x 6 columns]

# %%
#008 indexを1から振り直す
import numpy as np
Num_3_all.index=np.arange(1,len(Num_3_all)+1)

# %%
#009 indexを確認
Num_3_all
# Out:
#       No        date  Lottery_result  hundreds_place  tens_place  ones_place
# 1      1    2018/1/4             858               8           5           8
# 2      2    2018/1/5             384               3           8           4
# 3      3    2018/1/8             976               9           7           6
# 4      4    2018/1/9             930               9           3           0
# 5      5   2018/1/10             634               6           3           4
# ..   ...         ...             ...             ...         ...         ...
# 253  253  2018/12/24             329               3           2           9
# 254  254  2018/12/25             442               4           4           2
# 255  255  2018/12/26             644               6           4           4
# 256  256  2018/12/27              80               0           8           0
# 257  257  2018/12/28             234               2           3           4
#
# [257 rows x 6 columns]

# %%
#010 2010_2022 csv結合
import pandas as pd
Num_3_all=pd.DataFrame()
for file in Num_3_paths:
    Num_3_data=pd.read_csv(file)
    display(f'{file}:{len(Num_3_data)}')
    Num_3_all=pd.concat([Num_3_all,Num_3_data],ignore_index=True)
# Out:
# 'Num_3_predict/00_input/Num_3_2018.csv:257'
# 'Num_3_predict/00_input/Num_3_2019.csv:257'
# 'Num_3_predict/00_input/Num_3_2020.csv:258'
# 'Num_3_predict/00_input/Num_3_2021.csv:259'
# 'Num_3_predict/00_input/Num_3_2022.csv:259'

# %%
#011 ファイル確認
Num_3_all
# Out:
#        No        date  Lottery_result  hundreds_place  tens_place  ones_place
# 0       1    2018/1/4             858               8           5           8
# 1       2    2018/1/5             384               3           8           4
# 2       3    2018/1/8             976               9           7           6
# 3       4    2018/1/9             930               9           3           0
# 4       5   2018/1/10             634               6           3           4
# ...   ...         ...             ...             ...         ...         ...
# 1285  255  2022/12/26             857               8           5           7
# 1286  256  2022/12/27             929               9           2           9
# 1287  257  2022/12/28             958               9           5           8
# 1288  258  2022/12/29             194               1           9           4
# 1289  259  2022/12/30             953               9           5           3
#
# [1290 rows x 6 columns]

# %%
#012 ファイルの欠損値確認
Num_3_all.isnull().sum()
# Out:
# No                0
# date              0
# Lottery_result    0
# hundreds_place    0
# tens_place        0
# ones_place        0
# dtype: int64

# %%
#013 作成したNum_3_all ファイルを出力
data_file='Num_3_all.csv'
Num_3_all.to_csv(os.path.join(output_dir,data_file),index=False)

# %%
#014  csvデータを確認
Num_3_all
# Out:
#        No        date  Lottery_result  hundreds_place  tens_place  ones_place
# 0       1    2018/1/4             858               8           5           8
# 1       2    2018/1/5             384               3           8           4
# 2       3    2018/1/8             976               9           7           6
# 3       4    2018/1/9             930               9           3           0
# 4       5   2018/1/10             634               6           3           4
# ...   ...         ...             ...             ...         ...         ...
# 1285  255  2022/12/26             857               8           5           7
# 1286  256  2022/12/27             929               9           2           9
# 1287  257  2022/12/28             958               9           5           8
# 1288  258  2022/12/29             194               1           9           4
# 1289  259  2022/12/30             953               9           5           3
#
# [1290 rows x 6 columns]

# %%
#015 indexを回別1～振り直し
Num_3_all['kaibetu']=range(1,len(Num_3_all.index)+1)

# %%
#016 csvデータを確認
Num_3_all
# Out:
#        No        date  Lottery_result  hundreds_place  tens_place  ones_place  \
# 0       1    2018/1/4             858               8           5           8
# 1       2    2018/1/5             384               3           8           4
# 2       3    2018/1/8             976               9           7           6
# 3       4    2018/1/9             930               9           3           0
# 4       5   2018/1/10             634               6           3           4
# ...   ...         ...             ...             ...         ...         ...
# 1285  255  2022/12/26             857               8           5           7
# 1286  256  2022/12/27             929               9           2           9
# 1287  257  2022/12/28             958               9           5           8
# 1288  258  2022/12/29             194               1           9           4
# 1289  259  2022/12/30             953               9           5           3
#
#       kaibetu
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
# ...       ...
# 1285     1286
# 1286     1287
# 1287     1288
# 1288     1289
# 1289     1290
#
# [1290 rows x 7 columns]

# %%
#020 object を datetime に変換
Num_3_all['date']=pd.to_datetime(Num_3_all['date'])

# %%
#016 day of week をダミー変数化 challenge_２で変数へ変換へ変更
"""
import pandas as pd
import os
import glob

Num_3_all.loc[Num_3_all['day of week']=='Monday','week_flag']='1'
Num_3_all.loc[Num_3_all['day of week']=='Tuesday','week_flag']='2'
Num_3_all.loc[Num_3_all['day of week']=='Wednesday','week_flag']='3'
Num_3_all.loc[Num_3_all['day of week']=='Thursday','week_flag']='4'
Num_3_all.loc[Num_3_all['day of week']=='Friday','week_flag']='5'
Num_3_all.loc[Num_3_all['day of week']=='Saturday','week_flag']='6'
Num_3_all.loc[Num_3_all['day of week']=='Sunday','week_flag']='7'

data_file='Num_3_all.csv'
Num_3_all.to_csv(os.path.join(output_dir,data_file),index=False)
"""
# Out:
# "\nimport pandas as pd\nimport os\nimport glob\n\nNum_3_all.loc[Num_3_all['day of week']=='Monday','week_flag']='1'\nNum_3_all.loc[Num_3_all['day of week']=='Tuesday','week_flag']='2'\nNum_3_all.loc[Num_3_all['day of week']=='Wednesday','week_flag']='3'\nNum_3_all.loc[Num_3_all['day of week']=='Thursday','week_flag']='4'\nNum_3_all.loc[Num_3_all['day of week']=='Friday','week_flag']='5'\nNum_3_all.loc[Num_3_all['day of week']=='Saturday','week_flag']='6'\nNum_3_all.loc[Num_3_all['day of week']=='Sunday','week_flag']='7'\n\ndata_file='Num_3_all.csv'\nNum_3_all.to_csv(os.path.join(output_dir,data_file),index=False)\n"

# %%
#016 曜日と曜日の変数を取得
Num_3_all['day_of_week']=Num_3_all['date'].dt.day_of_week
Num_3_all['day_name']=Num_3_all['date'].dt.day_name()

# %%
#017 csvデータを確認
Num_3_all
# Out:
#        No       date  Lottery_result  hundreds_place  tens_place  ones_place  \
# 0       1 2018-01-04             858               8           5           8
# 1       2 2018-01-05             384               3           8           4
# 2       3 2018-01-08             976               9           7           6
# 3       4 2018-01-09             930               9           3           0
# 4       5 2018-01-10             634               6           3           4
# ...   ...        ...             ...             ...         ...         ...
# 1285  255 2022-12-26             857               8           5           7
# 1286  256 2022-12-27             929               9           2           9
# 1287  257 2022-12-28             958               9           5           8
# 1288  258 2022-12-29             194               1           9           4
# 1289  259 2022-12-30             953               9           5           3
#
#       kaibetu  day_of_week   day_name
# 0           1            3   Thursday
# 1           2            4     Friday
# 2           3            0     Monday
# 3           4            1    Tuesday
# 4           5            2  Wednesday
# ...       ...          ...        ...
# 1285     1286            0     Monday
# 1286     1287            1    Tuesday
# 1287     1288            2  Wednesday
# 1288     1289            3   Thursday
# 1289     1290            4     Friday
#
# [1290 rows x 9 columns]

# %%
#018 ファイルの欠損値確認
Num_3_all.isnull().sum()
# Out:
# No                0
# date              0
# Lottery_result    0
# hundreds_place    0
# tens_place        0
# ones_place        0
# kaibetu           0
# day_of_week       0
# day_name          0
# dtype: int64

# %%
#019 data type 確認
Num_3_all.dtypes
# Out:
# No                         int64
# date              datetime64[ns]
# Lottery_result             int64
# hundreds_place             int64
# tens_place                 int64
# ones_place                 int64
# kaibetu                    int64
# day_of_week                int64
# day_name                  object
# dtype: object

# %%
#020 object を datetime に変換
#Num_3_all['date']=pd.to_datetime(Num_3_all['date'])

# %%
#021 int64をobjectに変換 0埋めの効果なかったので保留
#Num_3_all['Lottery_result']=pd.Series(Num_3_all['Lottery_result'],dtype=str)

# %%
#確認
Num_3_all
# Out:
#        No       date  Lottery_result  hundreds_place  tens_place  ones_place  \
# 0       1 2018-01-04             858               8           5           8
# 1       2 2018-01-05             384               3           8           4
# 2       3 2018-01-08             976               9           7           6
# 3       4 2018-01-09             930               9           3           0
# 4       5 2018-01-10             634               6           3           4
# ...   ...        ...             ...             ...         ...         ...
# 1285  255 2022-12-26             857               8           5           7
# 1286  256 2022-12-27             929               9           2           9
# 1287  257 2022-12-28             958               9           5           8
# 1288  258 2022-12-29             194               1           9           4
# 1289  259 2022-12-30             953               9           5           3
#
#       kaibetu  day_of_week   day_name
# 0           1            3   Thursday
# 1           2            4     Friday
# 2           3            0     Monday
# 3           4            1    Tuesday
# 4           5            2  Wednesday
# ...       ...          ...        ...
# 1285     1286            0     Monday
# 1286     1287            1    Tuesday
# 1287     1288            2  Wednesday
# 1288     1289            3   Thursday
# 1289     1290            4     Friday
#
# [1290 rows x 9 columns]

# %%
#csv出力
data_file='Num_3_all.csv'
Num_3_all.to_csv(os.path.join(output_dir,data_file),index=False)

# %%
#022 data type 確認
Num_3_all.dtypes
# Out:
# No                         int64
# date              datetime64[ns]
# Lottery_result             int64
# hundreds_place             int64
# tens_place                 int64
# ones_place                 int64
# kaibetu                    int64
# day_of_week                int64
# day_name                  object
# dtype: object

# %%
# 0埋め intなのでそのまま
#num=Num_3_all['Lottery_result']
#Num_3_all['Lottery_result']='{:0>3}'.format(num)
#Num_3_all['h_place']=num(fmt='%3d')

# %%
#023 折れ線グラフ
import pandas as pd
import matplotlib.pyplot as plt
x=Num_3_all['date']
y=Num_3_all['Lottery_result']
plt.figure(figsize=(15,5))
plt.plot(x,y)

# %%
#024 変数「date」をインデックスに設定
#Num_3_all='Num_3_predict/01_output/Num_3_All.csv'
#Num_3_data=pd.read_csv(Num_3_all,index_col='date')
#Num_3_data=pd.read_csv(Num_3_all,index_col='date',parse_dates=True)s

#Num_3_data.head()

# %%
#022 data type 確認
Num_3_data.dtypes
# Out:
# No                 int64
# date              object
# Lottery_result     int64
# hundreds_place     int64
# tens_place         int64
# ones_place         int64
# dtype: object

# %%
import pandas as pd
import numpy as np
from scipy import signal
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# %%
#024 SLT分解：元DATA = Trend + 季節性 + 残差　グラフで確認

#移動平均法を利用したモデル(加法モデルを仮定)
#1_設定した季節性の周期の移動平均を計算しトレンド成分とする
#2_原系列からトレンド成分を除去し季節成分（平均値を0に調整）を求める
#3_原系列からトレンド成分と季節成分を除去し残差を求める

# 成分分解
#result=seasonal_decompose(Num_3_all.Lottery_result, model='additive', period=100) #初期period=12
result=seasonal_decompose(Num_3_all.Lottery_result, model='date', period=100) #初期period=12
# グラフ化
result.plot()
plt.show()

# %%
#025
#移動平均法を利用した分解（乗法モデルを仮定）
# 成分分解
result=seasonal_decompose(Num_3_all.Lottery_result, model='multiplicative', period=100) #初期period=12
# グラフ化
result.plot()
plt.show()

#乗算的な季節性は、ゼロと負の値には適切ではありません
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [38], line 4
#       1 #025
#       2 #移動平均法を利用した分解（乗法モデルを仮定）
#       3 # 成分分解
# ----> 4 result=seasonal_decompose(Num_3_all.Lottery_result, model='multiplicative', period=100) #初期period=12
#       5 # グラフ化
#       6 result.plot()
#
# File /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/seasonal.py:149, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     147 if model.startswith("m"):
#     148     if np.any(x <= 0):
# --> 149         raise ValueError(
#     150             "Multiplicative seasonality is not appropriate "
#     151             "for zero and negative values"
#     152         )
#     154 if period is None:
#     155     if pfreq is not None:
#
# ValueError: Multiplicative seasonality is not appropriate for zero and negative values

# %%
#026
#STL分解（LOESS平滑化を利用した分解）
# 成分分解
stl=STL(Num_3_all.Lottery_result, period=100, robust=True).fit() #初期period=12
# STL分解結果のグラフ化
stl.plot()
plt.show()

# %%
#025
# 自己相関（原系列）
acf = plot_acf(Num_3_all.Lottery_result, lags=40)
pacf = plot_pacf(Num_3_all.Lottery_result, lags=40)
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
#026
#ADF統計量の基準
#p値(p-value)<0.01 1%優位***一番厳しい
#p値(p-value)<0.05 5%優位***一般的
#p値(p-value)<0.10 10%優位***ゆるい

# ADF検定（原系列）
#dftest = adfuller(df.Passengers)
dftest = adfuller(Num_3_all.Lottery_result)
print('ADF Statistic: %f' % dftest[0])
print('p-value: %f' % dftest[1])
print('Critical values :')
for k, v in dftest[4].items():
    print('\t', k, v)

#帰無仮説（時系列は非定常である）は棄却できませんでした。
# Out:
# ADF Statistic: -36.029647
# p-value: 0.000000
# Critical values :
# 	 1% -3.435433297366533
# 	 5% -2.863784847800804
# 	 10% -2.5679651739400224

# %%
#027
# 対数変換
df_log = np.log(Num_3_all.Lottery_result)
plt.plot(df_log)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/arraylike.py:405: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#028
# ADF検定（対数系列）
#df_log = np.log(Num_3_all.Lottery_result)
dftest_1 = adfuller(df_log)
dftest=round(dftest_1,2)
#dftest = adfuller(Num_3_all.Lottery_result)
print('ADF Statistic: %f' % dftest[0])
print('p-value: %f' % dftest[1])
print('Critical values :')
for k, v in dftest[4].items():
    print('\t', k, v)

#inf nan はゼロや無限大があると適切でない
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In [43], line 4
#       1 #028
#       2 # ADF検定（対数系列）
#       3 #df_log = np.log(Num_3_all.Lottery_result)
# ----> 4 dftest_1 = adfuller(df_log)
#       5 dftest=round(dftest_1,2)
#       6 #dftest = adfuller(Num_3_all.Lottery_result)
#
# File /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:321, in adfuller(x, maxlag, regression, autolag, store, regresults)
#     315 # 1 for level
#     316 # search for lag length with smallest information criteria
#     317 # Note: use the same number of observations to have comparable IC
#     318 # aic and bic: smaller is better
#     320 if not regresults:
# --> 321     icbest, bestlag = _autolag(
#     322         OLS, xdshort, fullRHS, startlag, maxlag, autolag
#     323     )
#     324 else:
#     325     icbest, bestlag, alres = _autolag(
#     326         OLS,
#     327         xdshort,
#    (...)
#     332         regresults=regresults,
#     333     )
#
# File /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:130, in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#     128 for lag in range(startlag, startlag + maxlag + 1):
#     129     mod_instance = mod(endog, exog[:, :lag], *modargs)
# --> 130     results[lag] = mod_instance.fit()
#     132 if method == "aic":
#     133     icbest, bestlag = min((v.aic, k) for k, v in results.items())
#
# File /opt/conda/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:312, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     310         # Cache these singular values for use later.
#     311         self.wexog_singular_values = singular_values
# --> 312         self.rank = np.linalg.matrix_rank(np.diag(singular_values))
#     314     beta = np.dot(self.pinv_wexog, self.wendog)
#     316 elif method == "qr":
#
# File <__array_function__ internals>:180, in matrix_rank(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/numpy/linalg/linalg.py:1898, in matrix_rank(A, tol, hermitian)
#    1896 if A.ndim < 2:
#    1897     return int(not all(A==0))
# -> 1898 S = svd(A, compute_uv=False, hermitian=hermitian)
#    1899 if tol is None:
#    1900     tol = S.max(axis=-1, keepdims=True) * max(A.shape[-2:]) * finfo(S.dtype).eps
#
# File <__array_function__ internals>:180, in svd(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/numpy/linalg/linalg.py:1669, in svd(a, full_matrices, compute_uv, hermitian)
#    1666     gufunc = _umath_linalg.svd_n
#    1668 signature = 'D->d' if isComplexType(t) else 'd->d'
# -> 1669 s = gufunc(a, signature=signature, extobj=extobj)
#    1670 s = s.astype(_realType(result_t), copy=False)
#    1671 return s
#
# File /opt/conda/lib/python3.9/site-packages/numpy/linalg/linalg.py:98, in _raise_linalgerror_svd_nonconvergence(err, flag)
#      97 def _raise_linalgerror_svd_nonconvergence(err, flag):
# ---> 98     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
#データの数値を確認して丸めて無限大を消した
df_log = np.log(Num_3_all.Lottery_result)
x_num=round(df_log,2)
x_num
# Out:
# 0       6.75
# 1       5.95
# 2       6.88
# 3       6.84
# 4       6.45
#         ...
# 1285    6.75
# 1286    6.83
# 1287    6.86
# 1288    5.27
# 1289    6.86
# Name: Lottery_result, Length: 1290, dtype: float64

# %%
#有限数のときに True (inf, -inf, nan など) の場合は False
import math
df_log=math.inf
x_num= math.isfinite(df_log)
x_num
# Out:
# False

# %%
#ゼロを消すと

# %%
#028
# 階差
df_log_diff1 = df_log.diff(1).dropna()
plt.plot(df_log_diff1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [46], line 3
#       1 #028
#       2 # 階差
# ----> 3 df_log_diff1 = df_log.diff(1).dropna()
#       4 plt.plot(df_log_diff1)
#
# AttributeError: 'float' object has no attribute 'diff'

# %%
#029
# ADF検定
df_log_diff1 = df_log.diff(1).dropna()
dftest = adfuller(df_log_diff1)
#dftest = adfuller(Num_3_all.Lottery_result)
print('ADF Statistic: %f' % dftest[0])
print('p-value: %f' % dftest[1])
print('Critical values :')
for k, v in dftest[4].items():
    print('\t', k, v)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [47], line 3
#       1 #029
#       2 # ADF検定
# ----> 3 df_log_diff1 = df_log.diff(1).dropna()
#       4 dftest = adfuller(df_log_diff1)
#       5 #dftest = adfuller(Num_3_all.Lottery_result)
#
# AttributeError: 'float' object has no attribute 'diff'

# %%
import numpy as np

# nanの確認:0ならnanは存在しない
#print(np.isnan(x).sum())
print(exog.isnan(x).sum())

# infの確認:0ならinfは存在しない
#print(np.isinf(x).sum())
print(exog.isinf(x).sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [48], line 5
#       1 import numpy as np
#       3 # nanの確認:0ならnanは存在しない
#       4 #print(np.isnan(x).sum())
# ----> 5 print(exog.isnan(x).sum())
#       7 # infの確認:0ならinfは存在しない
#       8 #print(np.isinf(x).sum())
#       9 print(exog.isinf(x).sum())
#
# NameError: name 'exog' is not defined

# %%
#030 欠損値NaN＿なければFalse
print(Num_3_all.isnull())
# Out:
#          No   date  Lottery_result  hundreds_place  tens_place  ones_place  \
# 0     False  False           False           False       False       False
# 1     False  False           False           False       False       False
# 2     False  False           False           False       False       False
# 3     False  False           False           False       False       False
# 4     False  False           False           False       False       False
# ...     ...    ...             ...             ...         ...         ...
# 1285  False  False           False           False       False       False
# 1286  False  False           False           False       False       False
# 1287  False  False           False           False       False       False
# 1288  False  False           False           False       False       False
# 1289  False  False           False           False       False       False
#
#       kaibetu  day_of_week  day_name
# 0       False        False     False
# 1       False        False     False
# 2       False        False     False
# 3       False        False     False
# 4       False        False     False
# ...       ...          ...       ...
# 1285    False        False     False
# 1286    False        False     False
# 1287    False        False     False
# 1288    False        False     False
# 1289    False        False     False
#
# [1290 rows x 9 columns]

# %%
#031 欠損値NaN_なければFalse
print(Num_3_all.isna())
# Out:
#          No   date  Lottery_result  hundreds_place  tens_place  ones_place  \
# 0     False  False           False           False       False       False
# 1     False  False           False           False       False       False
# 2     False  False           False           False       False       False
# 3     False  False           False           False       False       False
# 4     False  False           False           False       False       False
# ...     ...    ...             ...             ...         ...         ...
# 1285  False  False           False           False       False       False
# 1286  False  False           False           False       False       False
# 1287  False  False           False           False       False       False
# 1288  False  False           False           False       False       False
# 1289  False  False           False           False       False       False
#
#       kaibetu  day_of_week  day_name
# 0       False        False     False
# 1       False        False     False
# 2       False        False     False
# 3       False        False     False
# 4       False        False     False
# ...       ...          ...       ...
# 1285    False        False     False
# 1286    False        False     False
# 1287    False        False     False
# 1288    False        False     False
# 1289    False        False     False
#
# [1290 rows x 9 columns]

# %%
##ここまで
