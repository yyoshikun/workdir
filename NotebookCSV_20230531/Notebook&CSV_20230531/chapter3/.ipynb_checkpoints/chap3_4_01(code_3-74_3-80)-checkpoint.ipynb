# %% [markdown]
# __<span style="background-color:#ffffe0">第3章　時系列予測モデル構築・超入門</span>__

# %% [markdown]
# # 3.4　季節成分が複数ある場合の予測モデル

# %% [markdown]
# ## 3.4.1　MSTLで複数の季節成分を分解

# %% [markdown]
# ### 準備（必要なモジュールとデータの読み込み）

# %%
#
# 必要なモジュールの読み込み
#

import numpy as np
import pandas as pd

import statsmodels.api as sm

import rpy2
# %load_ext rpy2.ipython

import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
plt.style.use('ggplot') #グラフのスタイル
plt.rcParams['figure.figsize'] = [12, 9] # グラフサイズ設定
plt.rcParams['font.size'] = 14 #フォントサイズ
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       6 import pandas as pd
#       8 import statsmodels.api as sm
# ---> 10 import rpy2
#      11 get_ipython().run_line_magic('load_ext', 'rpy2.ipython')
#      13 import warnings
#
# ModuleNotFoundError: No module named 'rpy2'

# %%
#
# 必要なデータセット（時系列データ）の読み込み
#

dataset = sm.datasets.get_rdataset(
    "taylor", "forecast")

print(dataset.data) #確認
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 #
#       2 # 必要なデータセット（時系列データ）の読み込み
#       3 #
# ----> 5 dataset = sm.datasets.get_rdataset(
#       6     "taylor", "forecast")
#       8 print(dataset.data)
#
# NameError: name 'sm' is not defined

# %%
#
# 時系列データのグラフ化（折れ線グラフ）
#

dataset.data.plot()
plt.show()

# %% [markdown]
# ### RのMSTLで分解

# %%
# R環境からPython環境へオブジェクトを渡す

y = dataset.data.x #R環境に渡すデータをyに格納
# %R -i y            #yをR環境に渡す
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # R環境からPython環境へオブジェクトを渡す
# ----> 3 y = dataset.data.x #R環境に渡すデータをyに格納
#       4 get_ipython().run_line_magic('R', '-i y            #yをR環境に渡す')
#
# NameError: name 'dataset' is not defined

# %%
# %%R
#
# # Rのforecastライブラリーの読み込み
# library(forecast)
#
# # 時系列オブジェクトに変換
# y = msts(y, seasonal.periods=c(48,336))
#
# # MSTLで分解
# y_mstl = mstl(y)
#
# # グラフ化
# autoplot(y_mstl)
# Out:
# R[write to console]: Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %% [markdown]
# ### Python環境でグラフ表示

# %%
# Python環境からR環境へオブジェクトを渡す

# %R -o y_mstl

# %%
#
# グラフ表示
#

fig, ax = plt.subplots(5,1, figsize=[10,10])

# グラフの描写
ax[0].plot(y_mstl[:,0]) #Data
ax[1].plot(y_mstl[:,1]) #Trend
ax[2].plot(y_mstl[:,2]) #Seasonal48
ax[3].plot(y_mstl[:,3]) #Seasonal336
ax[4].plot(y_mstl[:,4]) #Remainder

# 各グラフのタイトル
ax[0].title.set_text('Data')
ax[1].title.set_text('Trend')
ax[2].title.set_text('Seasonal48')
ax[3].title.set_text('Seasonal336')
ax[4].title.set_text('Remainder')

fig.tight_layout()
plt.show()
