# %%
import pandas as pd
df=pd.read_csv('Numbers3.csv')
df.head(3)
# Out:
#    issue number        date  number  place1  place2  place3 day of week  year  \
# 0             1   1994/10/7     191       1       9       1      Friday  1994
# 1             2  1994/10/14     988       9       8       8      Friday  1994
# 2             3  1994/10/21     194       1       9       4      Friday  1994
#
#    month  day
# 0     10    7
# 1     10   14
# 2     10   21

# %%
df.isnull().any(axis=0)
# Out:
# issue number    False
# date            False
# number          False
# place1          False
# place2          False
# place3          False
# day of week     False
# year            False
# month           False
# day             False
# dtype: bool

# %%
df2=df.fillna(df.mean())
df2.isnull().any(axis=0)
# Out:
# C:\Users\yoshikoshi\AppData\Local\Temp\ipykernel_8884\3719856547.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2=df.fillna(df.mean())
# issue number    False
# date            False
# number          False
# place1          False
# place2          False
# place3          False
# day of week     False
# year            False
# month           False
# day             False
# dtype: bool

# %%
# %matplotlib inline
df2.plot(kind='scatter',x='issue number',y='number')
# Out:
# <Axes: xlabel='issue number', ylabel='number'>

# %%
df2.plot(kind='scatter',x='place1',y='number')
df2.plot(kind='scatter',x='place2',y='number')
df2.plot(kind='scatter',x='place3',y='number')
df2.plot(kind='scatter',x='day of week',y='number')
df2.plot(kind='scatter',x='year',y='number')
df2.plot(kind='scatter',x='month',y='number')
df2.plot(kind='scatter',x='day',y='number')
df2.plot(kind='scatter',x= 'issue number',y='number')
# Out:
# <Axes: xlabel='issue number', ylabel='number'>

# %%
for name in df2.columns:
    if name=='cinema_id' or name == 'number':
        continue
    df2.plot(kind='scatter',x=name,y='number')

# %%
no=df2[(df2['SNS2'] > 1000) & (df2['sales'] < 8500)].index
df3=df2.drop(no,axis=0)

# %%
test=pd.DataFrame({'Acolumn':[1,2,3],'Bcolumn':[4,5,6]})

# %%
test[test['Acolumn'] < 2]

# %%
test['Acolumn'] < 2

# %%
df[(df['SNS2'] > 1000) & (df['sales'] < 8500)]

# %%
no=df2[(df['SNS2'] > 1000) & (df['sales'] < 8500)].index
no

# %%
test.drop(0, axis=0)

# %%
test.drop('Bcolumn', axis=1)

# %%
df3=df2.drop(no,axis=0)
df3.shape

# %%
col=['SNS1','SNS2','actor','original']
x=df3[col]
t=df3['sales']

# %%
df3.loc[2,'SNS1']

# %%
index=[2,4,6]
col=['SNS1','actor']
df3.loc[index,col]

# %%
df3.loc[2,'SNS1']

# %%
index=[2,4,6]
col=['SNS1','actor']
df3.loc[index,col]

# %%
sample=[10,20,30,40]
sample[1:3]

# %%
df3.loc[0:3, :'actor']

# %%
x=df3.loc[:, 'SNS1':'original']
t=df3['sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,t,test_size=0.2,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,t,test_size=0.2,random_state=0)
#
# NameError: name 'x' is not defined

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
new=[[150,700,300,0]]
model.predict(new)

# %%
new=[[150,700,300,1]]
model.predict(new)

# %%
model.score(x_test,y_test)

# %%
from sklearn.metrics import mean_absolute_error
pred=model.predict(x_test)
mean_absolute_error(y_pred=pred,y_true=y_test)

# %%
model.score(x_test,y_test)

# %%
import pickle
with open('cinema.pkl','wb')as f:
    pickle.dump(model, f)

# %%
print(model.coef_)
print(model.intercept_)

# %%
tmp=pd.DataFrame(model.coef_)
tmp.index=x_train.columns
tmp
